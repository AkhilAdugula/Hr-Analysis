# %%
# Importing the libraries
import pandas as pd
# Import Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
# Import train_test_split function
from sklearn.model_selection import train_test_split
#Import scikit-learn metrics module for accuracy calculation
from sklearn.metrics import accuracy_score
from sklearn import metrics 
#Import scikit-learn naive bayes for Gaussian Naive Bayes model accuracy
from sklearn.naive_bayes import GaussianNB
#Importing the CSV file
hr_data=pd.read_csv('train_LZdllcl.csv')
#Deleting the coloumn 'is_promoted'
X=hr_data.drop(columns=['is_promoted'])
#From hr data printing the is_promoted coloumn and storing it in Y
Y=hr_data['is_promoted']
X
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
#Filling all the NAN values with zero
X=X.fillna(0)
#converting the gender string attribute to numerical data
gender_=X.gender.value_counts().to_dict()
X.gender=X.gender.map(gender_)
X
# Out:
#        employee_id         department     region         education  gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above   16312
# 1            65141         Operations  region_22        Bachelor's   38496
# 2             7513  Sales & Marketing  region_19        Bachelor's   38496
# 3             2542  Sales & Marketing  region_23        Bachelor's   38496
# 4            48945         Technology  region_26        Bachelor's   38496
# ...            ...                ...        ...               ...     ...
# 54803         3030         Technology  region_14        Bachelor's   38496
# 54804        74592         Operations  region_27  Master's & above   16312
# 54805        13918          Analytics   region_1        Bachelor's   38496
# 54806        13614  Sales & Marketing   region_9                 0   38496
# 54807        51526                 HR  region_22        Bachelor's   38496
#
# ...

# %%
#converting the departmen string attribute to numerical data
department_=X.department.value_counts().to_dict()
X.department=X.department.map(department_)
X
# Out:
#        employee_id  department     region         education  gender  \
# 0            65438       16840   region_7  Master's & above   16312
# 1            65141       11348  region_22        Bachelor's   38496
# 2             7513       16840  region_19        Bachelor's   38496
# 3             2542       16840  region_23        Bachelor's   38496
# 4            48945        7138  region_26        Bachelor's   38496
# ...            ...         ...        ...               ...     ...
# 54803         3030        7138  region_14        Bachelor's   38496
# 54804        74592       11348  region_27  Master's & above   16312
# 54805        13918        5352   region_1        Bachelor's   38496
# 54806        13614       16840   region_9                 0   38496
# 54807        51526        2418  region_22        Bachelor's   38496
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   35                   5.0
# ...

# %%
#converting the region string attribute to numerical data
region_=X.region.value_counts().to_dict()
X.region=X.region.map(region_)

X
# Out:
#        employee_id  department  region         education  gender  \
# 0            65438       16840    4843  Master's & above   16312
# 1            65141       11348    6428        Bachelor's   38496
# 2             7513       16840     874        Bachelor's   38496
# 3             2542       16840    1175        Bachelor's   38496
# 4            48945        7138    2260        Bachelor's   38496
# ...            ...         ...     ...               ...     ...
# 54803         3030        7138     827        Bachelor's   38496
# 54804        74592       11348    1659  Master's & above   16312
# 54805        13918        5352     610        Bachelor's   38496
# 54806        13614       16840     420                 0   38496
# 54807        51526        2418    6428        Bachelor's   38496
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   35                   5.0
# ...

# %%
#converting the education string attribute to numerical data
education_=X.education.value_counts().to_dict()
X.education=X.education.map(education_)

X
# Out:
#        employee_id  department  region  education  gender recruitment_channel  \
# 0            65438       16840    4843      14925   16312            sourcing
# 1            65141       11348    6428      36669   38496               other
# 2             7513       16840     874      36669   38496            sourcing
# 3             2542       16840    1175      36669   38496               other
# 4            48945        7138    2260      36669   38496               other
# ...            ...         ...     ...        ...     ...                 ...
# 54803         3030        7138     827      36669   38496            sourcing
# 54804        74592       11348    1659      14925   16312               other
# 54805        13918        5352     610      36669   38496               other
# 54806        13614       16840     420       2409   38496            sourcing
# 54807        51526        2418    6428      36669   38496               other
#
# ...

# %%
#converting the recruitment_channel string attribute to numerical data
recruitment_channel_=X.recruitment_channel.value_counts().to_dict()
X.recruitment_channel=X.recruitment_channel.map(recruitment_channel_)
X
# Out:
#        employee_id  department  region  education  gender  \
# 0            65438       16840    4843      14925   16312
# 1            65141       11348    6428      36669   38496
# 2             7513       16840     874      36669   38496
# 3             2542       16840    1175      36669   38496
# 4            48945        7138    2260      36669   38496
# ...            ...         ...     ...        ...     ...
# 54803         3030        7138     827      36669   38496
# 54804        74592       11348    1659      14925   16312
# 54805        13918        5352     610      36669   38496
# 54806        13614       16840     420       2409   38496
# 54807        51526        2418    6428      36669   38496
#
#        recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                    23220                1   35                   5.0
# 1                    30446                1   30                   5.0
# ...

# %%
X=X.fillna(0)
# Spliting the dataset into training set and test set
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)
# Create Decision Tree classifier object
model=DecisionTreeClassifier()
# Train Decision Tree Classifier
model.fit(X_train,Y_train)
#Predict the response for test dataset
prediction=model.predict(X_test)
# Model Accuracy, how often is the classifier correct?
score=accuracy_score(Y_test, prediction)
score
# Out:
# 0.8977376391169495

# %%
# training the model on training set for Gaussian Naive Bayes Method
gnb = GaussianNB()
gnb.fit(X_train, Y_train)

# making predictions on the testing set
Y_pred = gnb.predict(X_test)

print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(Y_test, Y_pred)*100)
# Out:
# Gaussian Naive Bayes model accuracy(in %): 90.72249589490968

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier(criterion="entropy", max_depth=4)

# Train Decision Tree Classifer
clf = clf.fit(X_train,Y_train)

#Predict the response for test dataset
Y_pred = clf.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(Y_test, Y_pred)*100,"%") #Checking the accuracy of the predicted values to the actual test values at the depth 4 of decision tree
# Out:
# Accuracy: 92.99397920087576 %

# %%
#Defining the imortnat features to be used for plotting the graph
feature_imp = pd.Series(model.feature_importances_,index=X.columns).sort_values(ascending=False) 
feature_imp
# Out:
# avg_training_score      0.256185
# employee_id             0.202952
# department              0.117193
# age                     0.099061
# region                  0.070209
# length_of_service       0.068067
# previous_year_rating    0.042461
# KPIs_met >80%           0.041563
# awards_won?             0.023099
# recruitment_channel     0.022364
# gender                  0.020094
# no_of_trainings         0.019858
# education               0.016894
# dtype: float64

# %%
#To visualize the feature importance in decision tree
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Creating a bar plot
sns.barplot(x=feature_imp, y=feature_imp.index)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
p=pd.read_csv('test.csv')
p
# Out:
#        employee_id         department     region         education gender  \
# 0             8724         Technology  region_26        Bachelor's      m
# 1            74430                 HR   region_4        Bachelor's      f
# 2            72255  Sales & Marketing  region_13        Bachelor's      m
# 3            38562        Procurement   region_2        Bachelor's      f
# 4            64486            Finance  region_29        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 23485        53478              Legal   region_2   Below Secondary      m
# 23486        25600         Technology  region_25        Bachelor's      m
# 23487        45409                 HR  region_16        Bachelor's      f
# 23488         1186        Procurement  region_31        Bachelor's      m
# 23489         5973         Technology  region_17  Master's & above      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
p=p.fillna(0)
education_=p.education.value_counts().to_dict()
p.education=p.education.map(education_)

region_=p.region.value_counts().to_dict()
p.region=p.region.map(region_)

department_=p.department.value_counts().to_dict()
p.department=p.department.map(department_)

gender_=p.gender.value_counts().to_dict()
p.gender=p.gender.map(gender_)

recruitment_channel_=p.recruitment_channel.value_counts().to_dict()
p.recruitment_channel=p.recruitment_channel.map(recruitment_channel_)

p
# Out:
#        employee_id  department  region  education  gender  \
# 0             8724        3011    1011      15578   16596
# 1            74430        1085     775      15578    6894
# 2            72255        7315    1167      15578   16596
# 3            38562        3020    5299      15578    6894
# 4            64486        1091     414      15578   16596
# ...            ...         ...     ...        ...     ...
# 23485        53478         445    5299        374   16596
# 23486        25600        3011     337      15578   16596
# 23487        45409        1085     590      15578    6894
# 23488         1186        3020     844      15578   16596
# 23489         5973        3011     361       6504   16596
#
#        recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                     9961                1   24                   0.0
# 1                    13078                1   31                   3.0
# ...

# %%
s=model.predict(p)
s
# Out:
# array([0, 0, 0, ..., 0, 1, 0], dtype=int64)

# %%
k=pd.DataFrame(s)
j=p['employee_id']
h=pd.concat([j,k],axis=1)
h.columns={'employee_id','is_promoted'}
h
# Out:
#        employyee_id  is_promoted
# 0              8724            0
# 1             74430            0
# 2             72255            0
# 3             38562            0
# 4             64486            0
# ...             ...          ...
# 23485         53478            0
# 23486         25600            1
# 23487         45409            0
# 23488          1186            1
# 23489          5973            0
#
# [23490 rows x 2 columns]

# %%
h.to_csv('Akhil.csv')
z=pd.read_csv('Akhil.csv',index_col='employee_id')
z
# Out:
#              Unnamed: 0  is_promoted
# employee_id
# 8724                  0            0
# 74430                 1            0
# 72255                 2            0
# 38562                 3            0
# 64486                 4            0
# ...                 ...          ...
# 53478             23485            0
# 25600             23486            1
# 45409             23487            0
# 1186              23488            1
# 5973              23489            0
#
# [23490 rows x 2 columns]

# %%
q=z['is_promoted']
q
# Out:
# employee_id
# 8724     0
# 74430    0
# 72255    0
# 38562    0
# 64486    0
#         ..
# 53478    0
# 25600    1
# 45409    0
# 1186     1
# 5973     0
# Name: is_promoted, Length: 23490, dtype: int64

# %%
q.to_excel('dsproject_1.xlsx',sheet_name='new_example')
